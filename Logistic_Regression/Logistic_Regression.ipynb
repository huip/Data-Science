# %%
from sklearn.linear_model import LogisticRegression
import numpy as  np
import random

def true_classifier(i):
    if i >= 700:
        return 1
    return 0

x = np.array([random.randint(0, 1000) for i in range(0, 1000)])

x = x.reshape((-1, 1))

y = [true_classifier(x[i][0]) for i in range(0, 1000)]

y = np.array(y)

# %%
# 其余方法有{'newton-cg','lbfgs'','sag'}
model = LogisticRegression(solver='liblinear')

model = model.fit(x, y)

samples = np.array([random.randint(0, 1000) for i in range(0, 100)])

samples = samples.reshape(-1, 1)

_class = model.predict(samples)

proba = model.predict_proba(samples)

num_accurate = 0

for i in range(0, 100):
    if (true_classifier(samples[i]) == (_class[i] == 1)):
        num_accurate = num_accurate + 1
    print("" + str(samples[i]) + ": 所属分类 " + str(_class[i]) + ", 概率" + str(proba[i]))
# Out:
# [865]: 所属分类 1, 概率[0.07987466 0.92012534]
# [349]: 所属分类 0, 概率[0.99414467 0.00585533]
# [544]: 所属分类 0, 概率[0.90640693 0.09359307]
# [987]: 所属分类 1, 概率[0.01426067 0.98573933]
# [11]: 所属分类 0, 概率[9.99958873e-01 4.11273362e-05]
# [493]: 所属分类 0, 概率[0.9534508 0.0465492]
# [168]: 所属分类 0, 概率[9.99587520e-01 4.12480151e-04]
# [472]: 所属分类 0, 概率[0.96537727 0.03462273]
# [51]: 所属分类 0, 概率[9.99925995e-01 7.40045919e-05]
# [978]: 所属分类 1, 概率[0.01624324 0.98375676]
# [816]: 所属分类 1, 概率[0.1513079 0.8486921]
# [216]: 所属分类 0, 概率[9.99165569e-01 8.34431189e-04]
# [368]: 所属分类 0, 概率[0.99227451 0.00772549]
# [340]: 所属分类 0, 概率[0.99486596 0.00513404]
# [263]: 所属分类 0, 概率[0.99833727 0.00166273]
# [517]: 所属分类 0, 概率[0.93505629 0.06494371]
# [411]: 所属分类 0, 概率[0.98557022 0.01442978]
# [287]: 所属分类 0, 概率[0.99763624 0.00236376]
# [513]: 所属分类 0, 概率[0.93853397 0.06146603]
# [605]: 所属分类 0, 概率[0.79812465 0.20187535]
# [597]: 所属分类 0, 概率[0.81639502 0.18360498]
# [183]: 所属分类 0, 概率[9.99485912e-01 5.14087796e-04]
# [425]: 所属分类 0, 概率[0.98233428 0.01766572]
# [634]: 所属分类 0, 概率[0.7208509 0.2791491]
# [514]: 所属分类 0, 概率[0.93768122 0.06231878]
# [101]: 所属分类 0, 概率[9.99845776e-01 1.54223936e-04]
# [733]: 所属分类 1, 概率[0.37628561 0.62371439]
# [377]: 所属分类 0, 概率[0.99119237 0.00880763]
# [604]: 所属分类 0, 概率[0.80048071 0.19951929]
# [801]: 所属分类 1, 概率[0.18181898 0.81818102]
# [878]: 所属分类 1, 概率[0.06692054 0.93307946]
# [872]: 所属分类 1, 概率[0.07263762 0.92736238]
# [984]: 所属分类 1, 概率[0.0148935 0.9851065]
# [409]: 所属分类 0, 概率[0.98598207 0.01401793]
# [227]: 所属分类 0, 概率[9.99019402e-01 9.80598314e-04]
# [34]: 所属分类 0, 概率[9.99942346e-01 5.76541089e-05]
# [561]: 所属分类 0, 概率[0.88296888 0.11703112]
# [813]: 所属分类 1, 概率[0.15705335 0.84294665]
# [172]: 所属分类 0, 概率[9.99562572e-01 4.37427872e-04]
# [730]: 所属分类 1, 概率[0.38668161 0.61331839]
# [640]: 所属分类 0, 概率[0.70277831 0.29722169]
# [690]: 所属分类 0, 概率[0.5315093 0.4684907]
# [843]: 所属分类 1, 概率[0.1070788 0.8929212]
# [868]: 所属分类 1, 概率[0.07669573 0.92330427]
# [626]: 所属分类 0, 概率[0.74387048 0.25612952]
# [623]: 所属分类 0, 概率[0.75217482 0.24782518]
# [64]: 所属分类 0, 概率[9.99910428e-01 8.95721865e-05]
# [331]: 所属分类 0, 概率[0.9954988 0.0045012]
# [819]: 所属分类 1, 概率[0.14573629 0.85426371]
# [96]: 所属分类 0, 概率[9.99856694e-01 1.43305787e-04]
# [385]: 所属分类 0, 概率[0.99010511 0.00989489]
# [445]: 所属分类 0, 概率[0.97644459 0.02355541]
# [302]: 所属分类 0, 概率[0.99705539 0.00294461]
# [937]: 所属分类 1, 概率[0.02926879 0.97073121]
# [934]: 所属分类 1, 概率[0.03054698 0.96945302]
# [559]: 所属分类 0, 概率[0.88597029 0.11402971]
# [543]: 所属分类 0, 概率[0.90764548 0.09235452]
# [946]: 所属分类 1, 概率[0.02573798 0.97426202]
# [604]: 所属分类 0, 概率[0.80048071 0.19951929]
# [547]: 所属分类 0, 概率[0.90260151 0.09739849]
# [247]: 所属分类 0, 概率[0.99868503 0.00131497]
# [327]: 所属分类 0, 概率[0.99575453 0.00424547]
# [242]: 所属分类 0, 概率[0.99877802 0.00122198]
# [953]: 所属分类 1, 概率[0.02328188 0.97671812]
# [712]: 所属分类 1, 概率[0.4509301 0.5490699]
# [227]: 所属分类 0, 概率[9.99019402e-01 9.80598314e-04]
# [660]: 所属分类 0, 概率[0.63802901 0.36197099]
# [712]: 所属分类 1, 概率[0.4509301 0.5490699]
# [965]: 所属分类 1, 概率[0.01959351 0.98040649]
# [645]: 所属分类 0, 概率[0.68721418 0.31278582]
# [479]: 所属分类 0, 概率[0.9617716 0.0382284]
# [441]: 所属分类 0, 概率[0.97775868 0.02224132]
# [449]: 所属分类 0, 概率[0.97505483 0.02494517]
# [997]: 所属分类 1, 概率[0.01233676 0.98766324]
# [7]: 所属分类 0, 概率[9.99961219e-01 3.87808536e-05]
# [971]: 所属分类 1, 概率[0.01797047 0.98202953]
# [405]: 所属分类 0, 概率[0.9867713 0.0132287]
# [137]: 所属分类 0, 概率[9.99738342e-01 2.61657534e-04]
# [508]: 所属分类 0, 概率[0.94263638 0.05736362]
# [588]: 所属分类 0, 概率[0.83538679 0.16461321]
# [67]: 所属分类 0, 概率[9.99906393e-01 9.36067358e-05]
# [980]: 所属分类 1, 概率[0.01578046 0.98421954]
# [152]: 所属分类 0, 概率[9.99673875e-01 3.26124650e-04]
# [854]: 所属分类 1, 概率[0.09258336 0.90741664]
# [248]: 所属分类 0, 概率[0.9986656 0.0013344]
# [928]: 所属分类 1, 概率[0.03326742 0.96673258]
# [701]: 所属分类 1, 概率[0.4911623 0.5088377]
# [191]: 所属分类 0, 概率[9.99421853e-01 5.78146541e-04]
# [650]: 所属分类 0, 概率[0.67121632 0.32878368]
# [519]: 所属分类 0, 概率[0.93324954 0.06675046]
# [985]: 所属分类 1, 概率[0.01467954 0.98532046]
# [519]: 所属分类 0, 概率[0.93324954 0.06675046]
# [14]: 所属分类 0, 概率[9.99957020e-01 4.29799053e-05]
# [750]: 所属分类 1, 概率[0.31972713 0.68027287]
# [579]: 所属分类 0, 概率[0.85276837 0.14723163]
# [192]: 所属分类 0, 概率[9.99413304e-01 5.86695525e-04]
# [25]: 所属分类 0, 概率[9.99949484e-01 5.05156950e-05]
# [688]: 所属分类 0, 概率[0.53881644 0.46118356]
# [889]: 所属分类 1, 概率[0.05751125 0.94248875]
# [677]: 所属分类 0, 概率[0.57862654 0.42137346]
